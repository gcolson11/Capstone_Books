# %% [markdown]
# # Pre-processing and Model

# %% [markdown]
# This is the Jupyter Notebook version of this section of the project. It contains all of the steps involved in pre-processing the data and then manually manipulating the data to create similarity scores to rank books. This file is beneficial because it produces visualizations of the dataframe step by step up until the final recommendations are produced. The main files used for this project however are .py files created in Atom. I used object oriented programming to make my code more reusable and callable, and I layered in a Web App using Streamlit to make this a more interactive project. Ultimately, this Notebook serves as a step by step guide of the modeling process.

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from statistics import pstdev
import random

# set preferences for displaying dataframes
pd.set_option('display.max_columns', None)

# %% [markdown]
# Attain the saved data files from the previous Data_Wrangling_and_EDA Notebook.

# %%
# read in the books and ratings dataframes
ratings = pd.read_csv("Data/ratings_cleaned.csv")
books = pd.read_csv("Data/books_cleaned.csv")

# %% [markdown]
# Let's look at the two datasets again to get a reminder of their structure

# %%
ratings.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
books.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# 2                                  Twilight
# 3                     To Kill a Mockingbird
# 4                          The Great Gatsby
#
#                                                title language_code  \
# 0            The Hunger Games (The Hunger Games, #1)           eng
# 1  Harry Potter and the Sorcerer's Stone (Harry P...           eng
# 2                            Twilight (Twilight, #1)         en-US
# 3                              To Kill a Mockingbird           eng
# 4                                   The Great Gatsby           eng
#
#    average_rating  ratings_count  work_ratings_count  work_text_reviews_count  \
# 0            4.34        4780653             4942365                   155254
# 1            4.44        4602479             4800065                    75867
# 2            3.57        3866839             3916824                    95009
# 3            4.25        3198671             3340896                    72586
# 4            3.89        2683664             2773745                    51992
#
#    ratings_1  ratings_2  ratings_3  ratings_4  ratings_5  \
# 0      66715     127936     560092    1481305    2706317
# 1      75504     101676     455024    1156318    3011543
# 2     456191     436802     793319     875073    1355439
# 3      60427     117415     446835    1001952    1714267
# 4      86236     197621     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url  goodreads_book_id  \
# 0  https://images.gr-assets.com/books/1447303603s...            2767052
# 1  https://images.gr-assets.com/books/1474154022s...                  3
# 2  https://images.gr-assets.com/books/1361039443s...              41865
# 3  https://images.gr-assets.com/books/1361975680s...               2657
# 4  https://images.gr-assets.com/books/1490528560s...               4671
#
#         genre1              genre2              genre3
# 0  young-adult             fiction             fantasy
# 1      fantasy         young-adult             fiction
# 2  young-adult             fantasy             fiction
# 3     classics  historical-fiction         young-adult
# 4     classics             fiction  historical-fiction

# %% [markdown]
# We're ready to start setting up the model.

# %% [markdown]
# ## Collaborative Filtering

# %% [markdown]
# I chose a collaborative filtering approach for my recommender. I used [this](https://medium.com/swlh/how-to-build-simple-recommender-systems-in-python-647e5bcd78bd#id_token=eyJhbGciOiJSUzI1NiIsImtpZCI6IjE3MTllYjk1N2Y2OTU2YjU4MThjMTk2OGZmMTZkZmY3NzRlNzA4ZGUiLCJ0eXAiOiJKV1QifQ.....WggZap4Lz64ddHAd04CbGvb-rzwoOR5RsRa9BMmnYEJ_ea52lpsv7rSk9josCYIxCFJgelHKbl6DcDrJ_m19rSHdzMSafpwnrOZzyA3mq6qsiti2tBcHabLR_4SnGaRBPaSpO0N9sa5i1NKC0Hn144cGiqhbpxBLVSdSEgfmW-evaMFY7_-Jk1zpY-i0cyWRyhxFCoSABcy_KfHCaHadHvFRcVeIhfMCkF_Ztb3_r1AQdOdV3I-QXOVzWPwgVaLO67FbsiC3I3pOHEtGveLslRIqOHeiK_mYbmn_jts_P14s2mrlbUwC1W9cCE6sj_All88jcZU4HqM5Rft4qSUi2Q) project by Bryan Tan as a guide to the steps involved in creating such a model. To begin, we need to create a simplified version of the books dataframe with only the essential attributes.

# %%
# make dataframe with only essential columns
books_cf = books[['id', 'title', 'authors', 'original_publication_year', 'genre1', 'genre2', 'genre3', 'small_image_url']].copy()
books_cf.head(50)
# Out:
#     id                                              title  \
# 0    1            The Hunger Games (The Hunger Games, #1)
# 1    2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2    3                            Twilight (Twilight, #1)
# 3    4                              To Kill a Mockingbird
# 4    5                                   The Great Gatsby
# 5    6                             The Fault in Our Stars
# 6    7                                         The Hobbit
# 7    8                             The Catcher in the Rye
# 8    9              Angels & Demons  (Robert Langdon, #1)
# 9   10                                Pride and Prejudice
# 10  11                                    The Kite Runner
# 11  12                          Divergent (Divergent, #1)
# 12  13                                               1984
# 13  14                                        Animal Farm
# 14  15                          The Diary of a Young Girl
# 15  16   The Girl with the Dragon Tattoo (Millennium, #1)
# 16  17               Catching Fire (The Hunger Games, #2)
# 17  18  Harry Potter and the Prisoner of Azkaban (Harr...
# 18  19  The Fellowship of the Ring (The Lord of the Ri...
# 19  20                  Mockingjay (The Hunger Games, #3)
# 20  21  Harry Potter and the Order of the Phoenix (Har...
# 21  22                                   The Lovely Bones
# 22  23  Harry Potter and the Chamber of Secrets (Harry...
# 23  24  Harry Potter and the Goblet of Fire (Harry Pot...
# 24  25  Harry Potter and the Deathly Hallows (Harry Po...
# 25  26             The Da Vinci Code (Robert Langdon, #2)
# 26  27  Harry Potter and the Half-Blood Prince (Harry ...
# 27  28                                  Lord of the Flies
# 28  29                                   Romeo and Juliet
# 29  30                                          Gone Girl
# 30  31                                           The Help
# 31  32                                    Of Mice and Men
# 32  33                                Memoirs of a Geisha
# 33  34            Fifty Shades of Grey (Fifty Shades, #1)
# 34  35                                      The Alchemist
# 35  36                          The Giver (The Giver, #1)
# 36  37  The Lion, the Witch, and the Wardrobe (Chronic...
# 37  38                           The Time Traveler's Wife
# 38  39     A Game of Thrones (A Song of Ice and Fire, #1)
# 39  40                                    Eat, Pray, Love
# 40  41  The Lightning Thief (Percy Jackson and the Oly...
# 41  42                    Little Women (Little Women, #1)
# 42  43                                          Jane Eyre
# 43  44                    The Notebook (The Notebook, #1)
# 44  45                                         Life of Pi
# 45  46                                Water for Elephants
# 46  47                                     The Book Thief
# 47  48                                     Fahrenheit 451
# 48  49                            New Moon (Twilight, #2)
# 49  50                            Where the Sidewalk Ends
#
#                                               authors  \
# 0                                     Suzanne Collins
# 1                         J.K. Rowling, Mary GrandPré
# 2                                     Stephenie Meyer
# 3                                          Harper Lee
# 4                                 F. Scott Fitzgerald
# 5                                          John Green
# 6                                      J.R.R. Tolkien
# 7                                       J.D. Salinger
# 8                                           Dan Brown
# 9                                         Jane Austen
# 10                                    Khaled Hosseini
# 11                                      Veronica Roth
# 12            George Orwell, Erich Fromm, Celâl Üster
# 13                                      George Orwell
# 14  Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-D...
# 15                         Stieg Larsson, Reg Keeland
# 16                                    Suzanne Collins
# 17            J.K. Rowling, Mary GrandPré, Rufus Beck
# 18                                     J.R.R. Tolkien
# 19                                    Suzanne Collins
# 20                        J.K. Rowling, Mary GrandPré
# 21                                       Alice Sebold
# 22                        J.K. Rowling, Mary GrandPré
# 23                        J.K. Rowling, Mary GrandPré
# 24                        J.K. Rowling, Mary GrandPré
# 25                                          Dan Brown
# 26                        J.K. Rowling, Mary GrandPré
# 27                                    William Golding
# 28      William Shakespeare, Robert           Jackson
# 29                                      Gillian Flynn
# 30                                   Kathryn Stockett
# 31                                     John Steinbeck
# 32                                      Arthur Golden
# 33                                         E.L. James
# 34                       Paulo Coelho, Alan R. Clarke
# 35                                         Lois Lowry
# 36                                         C.S. Lewis
# 37                                 Audrey Niffenegger
# 38                                 George R.R. Martin
# 39                                  Elizabeth Gilbert
# 40                                       Rick Riordan
# 41                                  Louisa May Alcott
# 42                    Charlotte Brontë, Michael Mason
# 43                                    Nicholas Sparks
# 44                                        Yann Martel
# 45                                         Sara Gruen
# 46                                       Markus Zusak
# 47                                       Ray Bradbury
# 48                                    Stephenie Meyer
# 49                                   Shel Silverstein
#
#     original_publication_year              genre1              genre2  \
# 0                      2008.0         young-adult             fiction
# 1                      1997.0             fantasy         young-adult
# 2                      2005.0         young-adult             fantasy
# 3                      1960.0            classics  historical-fiction
# 4                      1925.0            classics             fiction
# 5                      2012.0         young-adult             fiction
# 6                      1937.0             fantasy            classics
# 7                      1951.0            classics             fiction
# 8                      2000.0             fiction             mystery
# 9                      1813.0            classics             fiction
# 10                     2003.0             fiction  historical-fiction
# 11                     2011.0         young-adult             fiction
# 12                     1949.0             fiction     science-fiction
# 13                     1945.0            classics             fiction
# 14                     1947.0         non-fiction            classics
# 15                     2005.0             fiction             mystery
# 16                     2009.0         young-adult             fantasy
# 17                     1999.0             fantasy         young-adult
# 18                     1954.0             fantasy            classics
# 19                     2010.0         young-adult             fiction
# 20                     2003.0             fantasy            children
# 21                     2002.0             fiction             mystery
# 22                     1998.0             fantasy         young-adult
# 23                     2000.0             fantasy         young-adult
# 24                     2007.0             fantasy         young-adult
# 25                     2003.0             fiction            thriller
# 26                     2005.0             fantasy         young-adult
# 27                     1954.0            classics             fiction
# 28                     1595.0            classics             fiction
# 29                     2012.0             mystery               crime
# 30                     2009.0             fiction  historical-fiction
# 31                     1937.0            classics             fiction
# 32                     1997.0             fiction  historical-fiction
# 33                     2011.0             romance             fiction
# 34                     1988.0             fiction            classics
# 35                     1993.0            children             fiction
# 36                     1950.0             fantasy            classics
# 37                     2003.0             fiction             romance
# 38                     1996.0             fiction             fantasy
# 39                     2006.0         non-fiction              memoir
# 40                     2005.0             fantasy         young-adult
# 41                     1868.0            classics             fiction
# 42                     1847.0             fiction             mystery
# 43                     1996.0             fiction           chick-lit
# 44                     2001.0             fantasy            classics
# 45                     2006.0             fiction  historical-fiction
# 46                     2005.0  historical-fiction             fiction
# 47                     1953.0            classics             fiction
# 48                     2006.0         young-adult             fantasy
# 49                     1974.0              poetry            children
#
#                 genre3                                    small_image_url
# 0              fantasy  https://images.gr-assets.com/books/1447303603s...
# 1              fiction  https://images.gr-assets.com/books/1474154022s...
# 2              fiction  https://images.gr-assets.com/books/1361039443s...
# 3          young-adult  https://images.gr-assets.com/books/1361975680s...
# 4   historical-fiction  https://images.gr-assets.com/books/1490528560s...
# 5              romance  https://images.gr-assets.com/books/1360206420s...
# 6              fiction  https://images.gr-assets.com/books/1372847500s...
# 7          young-adult  https://images.gr-assets.com/books/1398034300s...
# 8             thriller  https://images.gr-assets.com/books/1303390735s...
# 9              romance  https://images.gr-assets.com/books/1320399351s...
# 10        contemporary  https://images.gr-assets.com/books/1484565687s...
# 11             fantasy  https://images.gr-assets.com/books/1328559506s...
# 12             fantasy  https://images.gr-assets.com/books/1348990566s...
# 13             fantasy  https://images.gr-assets.com/books/1424037542s...
# 14             history  https://images.gr-assets.com/books/1358276407s...
# 15            thriller  https://images.gr-assets.com/books/1327868566s...
# 16             romance  https://images.gr-assets.com/books/1358273780s...
# 17             fiction  https://images.gr-assets.com/books/1499277281s...
# 18             fiction  https://images.gr-assets.com/books/1298411339s...
# 19             fantasy  https://images.gr-assets.com/books/1358275419s...
# 20             fiction  https://images.gr-assets.com/books/1387141547s...
# 21         young-adult  https://images.gr-assets.com/books/1457810586s...
# 22             fiction  https://images.gr-assets.com/books/1474169725s...
# 23             fiction  https://images.gr-assets.com/books/1361482611s...
# 24             fiction  https://images.gr-assets.com/books/1474171184s...
# 25            suspense  https://images.gr-assets.com/books/1303252999s...
# 26             fiction  https://images.gr-assets.com/books/1361039191s...
# 27         young-adult  https://images.gr-assets.com/books/1327869409s...
# 28             romance  https://images.gr-assets.com/books/1327872146s...
# 29             fiction  https://images.gr-assets.com/books/1339602131s...
# 30           chick-lit  https://images.gr-assets.com/books/1346100365s...
# 31  historical-fiction  https://images.gr-assets.com/books/1437235233s...
# 32             romance  https://s.gr-assets.com/assets/nophoto/book/50...
# 33        contemporary  https://images.gr-assets.com/books/1385207843s...
# 34             fantasy  https://images.gr-assets.com/books/1483412266s...
# 35            classics  https://images.gr-assets.com/books/1342493368s...
# 36             fiction  https://images.gr-assets.com/books/1353029077s...
# 37             fantasy  https://images.gr-assets.com/books/1437728815s...
# 38     science-fiction  https://images.gr-assets.com/books/1436732693s...
# 39              travel  https://images.gr-assets.com/books/1503066414s...
# 40             fiction  https://images.gr-assets.com/books/1400602609s...
# 41         young-adult  https://s.gr-assets.com/assets/nophoto/book/50...
# 42             romance  https://images.gr-assets.com/books/1327867269s...
# 43             romance  https://images.gr-assets.com/books/1385738917s...
# 44        contemporary  https://images.gr-assets.com/books/1320562005s...
# 45             romance  https://images.gr-assets.com/books/1494428973s...
# 46         young-adult  https://images.gr-assets.com/books/1390053681s...
# 47     science-fiction  https://images.gr-assets.com/books/1351643740s...
# 48             romance  https://images.gr-assets.com/books/1361039440s...
# 49            classics  https://images.gr-assets.com/books/1168052448s...

# %% [markdown]
# We can clean up this dataframe a little more to make it easier to work with.

# %%
# convert original_publication_year to int, rename column to something shorter
books_cf['original_publication_year'] = books_cf['original_publication_year'].astype('Int64')
books_cf = books_cf.rename(columns={'original_publication_year': 'year'})

# %%
books_cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9942 entries, 0 to 9941
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               9942 non-null   int64
#  1   title            9942 non-null   object
#  2   authors          9942 non-null   object
#  3   year             9942 non-null   Int64
#  4   genre1           9942 non-null   object
#  5   genre2           9942 non-null   object
#  6   genre3           9942 non-null   object
#  7   small_image_url  9942 non-null   object
# dtypes: Int64(1), int64(1), object(6)
# memory usage: 631.2+ KB

# %%
# rename ratings book_id to id
ratings = ratings.rename(columns={'book_id': 'id'})

# %% [markdown]
# ### Sample User Input

# %% [markdown]
# Now that the data is ready to be used, let's create a sample user input to supplement an actual user input on the Web App.

# %%
# create sample dataframe with 5 book-rating pairs

user_input = [
    
    {'title': 'The Tipping Point: How Little Things Can Make a Big Difference', 'authors': 'Malcolm Gladwell', 'rating': 4},
    {'title': 'How to Win Friends and Influence People', 'authors': 'Dale Carnegie', 'rating': 5},
    {'title': 'The Power of Habit: Why We Do What We Do in Life and Business', 'authors': 'Charles Duhigg', 'rating': 5},
    {'title': 'Stumbling on Happiness', 'authors': 'Daniel Todd Gilbert', 'rating': 4},
    {'title': 'Flow: The Psychology of Optimal Experience', 'authors': 'Mihaly Csikszentmihalyi', 'rating': 5}
    
    #2 - an alternate testing user input
    #{'title': '1984', 'authors': 'George Orwell, Erich Fromm, Celâl Üster', 'rating': 5}
    #{'title': 'The Catcher in the Rye', 'authors': 'J.D. Salinger', 'rating': 5},
    #{'title': 'The Great Gatsby', 'authors': 'F. Scott Fitzgerald', 'rating': 4},
    #{'title': 'To Kill a Mockingbird', 'authors': 'Harper Lee', 'rating': 5},
    #{'title': 'Of Mice and Men', 'authors': 'John Steinbeck', 'rating': 5}

]

input_books = pd.DataFrame(user_input)
input_books
# Out:
#                                                title                  authors  \
# 0  The Tipping Point: How Little Things Can Make ...         Malcolm Gladwell
# 1            How to Win Friends and Influence People            Dale Carnegie
# 2  The Power of Habit: Why We Do What We Do in Li...           Charles Duhigg
# 3                             Stumbling on Happiness      Daniel Todd Gilbert
# 4         Flow: The Psychology of Optimal Experience  Mihaly Csikszentmihalyi
#
#    rating
# 0       4
# 1       5
# 2       5
# 3       4
# 4       5

# %% [markdown]
# This is good, but now let's begin to manipulate the data so that it is ready to be used to calculate Correlations

# %%
# filter the books by title, merge df's and drop year column
input_id = books_cf[books_cf['title'].isin(input_books['title'].tolist())]
input_books = pd.merge(input_id, input_books)
input_books = input_books.drop('year', axis=1)
input_books
# Out:
#      id                                              title  \
# 0   127  The Tipping Point: How Little Things Can Make ...
# 1   260            How to Win Friends and Influence People
# 2   537  The Power of Habit: Why We Do What We Do in Li...
# 3  2465                             Stumbling on Happiness
# 4  2946         Flow: The Psychology of Optimal Experience
#
#                    authors       genre1       genre2      genre3  \
# 0         Malcolm Gladwell  non-fiction     business  psychology
# 1            Dale Carnegie  non-fiction     classics  philosophy
# 2           Charles Duhigg      science  non-fiction  psychology
# 3      Daniel Todd Gilbert  non-fiction   psychology     science
# 4  Mihaly Csikszentmihalyi   psychology  non-fiction   self-help
#
#                                      small_image_url  rating
# 0  https://images.gr-assets.com/books/1473396980s...       4
# 1  https://images.gr-assets.com/books/1442726934s...       5
# 2  https://images.gr-assets.com/books/1366758683s...       5
# 3  https://images.gr-assets.com/books/1327947323s...       4
# 4  https://s.gr-assets.com/assets/nophoto/book/50...       5

# %%
# remove input books from books_cf 
input_book_list = input_books['id'].tolist()
books_cf = books_cf[~books_cf['id'].isin(input_book_list)]
books_cf.shape
# Out:
# (9937, 8)

# %%
# create a list of genres
genre_list = []
id_list = input_books['id'].tolist()

# for loop that appends unique genre tags to genre_list
for item in id_list:
    temp = books.loc[books['id'] == item]
    for i in range(24,27):
        a = temp.iloc[0, i]
        if a not in genre_list:
            genre_list.append(a)
            
genre_list
# Out:
# ['non-fiction',
#  'business',
#  'psychology',
#  'classics',
#  'philosophy',
#  'science',
#  'self-help']

# %%
# make average rating for each genre among user inputs
avg_genre_rating = []
for item in genre_list:
    temp_gdf = input_books.loc[(input_books['genre1'] == item) | \
                               (input_books['genre2'] == item) | \
                               (input_books['genre3'] == item)]
    c = temp_gdf['rating'].mean()
    avg_genre_rating.append(c)
avg_genre_rating
# Out:
# [4.6, 4.0, 4.5, 5.0, 5.0, 4.5, 5.0]

# %%
# create dictionary among the two lists
genre_rating_dict = {genre_list[i]: avg_genre_rating[i] for i in range(len(genre_list))}
genre_rating_dict
# Out:
# {'non-fiction': 4.6,
#  'business': 4.0,
#  'psychology': 4.5,
#  'classics': 5.0,
#  'philosophy': 5.0,
#  'science': 4.5,
#  'self-help': 5.0}

# %%
# filter users that have read books that the input has also read
user_subset = ratings[ratings['id'].isin(input_books['id'].tolist())]
user_subset.head()
# Out:
#         id  user_id  rating
# 12600  127      173       4
# 12601  127      588       4
# 12602  127     1449       4
# 12603  127     1456       4
# 12604  127     1759       3

# %%
# groupby user_id to create user subset group
user_subset_group = user_subset.groupby(['user_id'])

# %%
# sort so that users with book most in common with the input will have priority
user_subset_group = sorted(user_subset_group, key=lambda x: len(x[1]), reverse=True)
user_subset_group[0:5]
# Out:
# [(39720,
#             id  user_id  rating
#   12690    127    39720       2
#   25872    260    39720       4
#   245925  2465    39720       5
#   293947  2946    39720       4),
#  (14901,
#             id  user_id  rating
#   25825    260    14901       2
#   245876  2465    14901       2
#   293907  2946    14901       2),
#  (36206,
#             id  user_id  rating
#   53571    537    36206       5
#   245918  2465    36206       3
#   293939  2946    36206       5),
#  (47478,
#             id  user_id  rating
#   12697    127    47478       3
#   25884    260    47478       2
#   293963  2946    47478       3),
#  (1456,
#             id  user_id  rating
#   12603    127     1456       4
#   245844  2465     1456       5)]

# %%
# limit number of users we look through to top 100
user_subset_group = user_subset_group[0:100]

# %% [markdown]
# ### Calculating Similarities

# %% [markdown]
# We will manually calculate these correlations

# %%
# create dict of pearson correlation values
sim_dict = {}

std = pstdev(input_books['rating'].tolist())

# for loop that calculates Pearson correlation and stores values in above dict
for name, group in user_subset_group:
    
    group = group.sort_values(by='id')
    input_books = input_books.sort_values(by='id')
    num_ratings = len(group)
    
    # get the review scores for the books in common
    temp_df = input_books[input_books['id'].isin(group['id'].tolist())]

    # store both ratings in list for calculations        
    rating_list = temp_df['rating'].tolist()
    group_list = group['rating'].tolist()
    
    if std == 0:
    
        # calculate cosine similarity
        cos_sim = np.dot(rating_list, group_list)/(np.linalg.norm(rating_list)*np.linalg.norm(group_list))
        sim_dict[name] = cos_sim
        
    else:

        # calculate the pearson correlation between users 
        Sxx = sum([i**2 for i in rating_list]) - (sum(rating_list)**2 / float(num_ratings))
        Syy = sum([i**2 for i in group_list]) - (sum(group_list)**2 / float(num_ratings))
        Sxy = sum([i*j for i, j in zip(rating_list, group_list)]) - (sum(rating_list) * sum(group_list) / float(num_ratings))

        # calculate Pearson corr if Sxx and Syy not 0, else set = 0
        if Sxx != 0 and Syy != 0:
            sim_dict[name] = Sxy/sqrt(Sxx*Syy)
        else:
            sim_dict[name] = 0

# %%
# convert dictionary to dataframe
sim_df = pd.DataFrame.from_dict(sim_dict, orient='index')
sim_df.columns = ['similarity_index']
sim_df['user_id'] = sim_df.index
sim_df.index = range(len(sim_df))
sim_df.head()
# Out:
#    similarity_index  user_id
# 0          0.229416    39720
# 1          0.000000    14901
# 2          1.000000    36206
# 3         -0.500000    47478
# 4          0.000000     1456

# %%
# get top 50 similar users
top_users = sim_df.sort_values(by='similarity_index', ascending=False)[0:50]
top_users.head()
# Out:
#     similarity_index  user_id
# 15               1.0    25812
# 9                1.0    14136
# 28               1.0    37035
# 31               1.0    41282
# 5                1.0     1877

# %%
# merge top_users df with ratings 
top_users_rating = top_users.merge(ratings, left_on='user_id', right_on='user_id', how='inner')
top_users_rating.head()
# Out:
#    similarity_index  user_id   id  rating
# 0               1.0    25812  127       1
# 1               1.0    25812  182       5
# 2               1.0    25812  183       2
# 3               1.0    25812  190       1
# 4               1.0    25812  193       2

# %%
# multiply the user similarity by the user ratings
top_users_rating['weighted_rating'] = top_users_rating['similarity_index'] * top_users_rating['rating']
top_users_rating.head()
# Out:
#    similarity_index  user_id   id  rating  weighted_rating
# 0               1.0    25812  127       1              1.0
# 1               1.0    25812  182       5              5.0
# 2               1.0    25812  183       2              2.0
# 3               1.0    25812  190       1              1.0
# 4               1.0    25812  193       2              2.0

# %%
# apply a sum to the top_users after grouping it up by user_id
temp_top_users_rating = top_users_rating.groupby('id').sum()[['similarity_index','weighted_rating']]
temp_top_users_rating.columns = ['sum_similarity_index','sum_weighted_rating']
temp_top_users_rating.head()
# Out:
#     sum_similarity_index  sum_weighted_rating
# id
# 1               0.000000             0.000000
# 2               0.000000             0.000000
# 4               0.000000             0.000000
# 5               0.000000             0.000000
# 6               1.229416             4.917663

# %% [markdown]
# ### Recommmendations

# %% [markdown]
# Finally, we can use the weighted rating and similarty index to calculate the weighted average recommendation score to be used to give recommendations.

# %%
# create an empty dataframe
recommendation_df = pd.DataFrame()

# find the weighted average
recommendation_df['weighted average recommendation score'] = temp_top_users_rating['sum_weighted_rating'] / temp_top_users_rating['sum_similarity_index']
recommendation_df['id'] = temp_top_users_rating.index
recommendation_df.head()
# Out:
#     weighted average recommendation score  id
# id
# 1                                     NaN   1
# 2                                     NaN   2
# 4                                     NaN   4
# 5                                     NaN   5
# 6                                     4.0   6

# %%
# sort values in order of highest weights descending
recommendation_df = recommendation_df.sort_values(by='weighted average recommendation score', ascending=False)
recommendation_df.head(10)
# Out:
#       weighted average recommendation score    id
# id
# 9999                                    5.0  9999
# 663                                     5.0   663
# 4389                                    5.0  4389
# 4356                                    5.0  4356
# 1280                                    5.0  1280
# 501                                     5.0   501
# 4080                                    5.0  4080
# 537                                     5.0   537
# 545                                     5.0   545
# 3910                                    5.0  3910

# %%
# check the number of books that have perfect 5's as a recommendation score
fives = recommendation_df.loc[recommendation_df['weighted average recommendation score'] == 5]
len(fives)
# Out:
# 180

# %%
if len(fives) > 10:
    
    count = 0
    scores = []
    
    # calculate genre score for each book
    for index, row in books_cf.iterrows():
        if row['genre1'] in genre_list:
            count += 5 * (genre_rating_dict[row['genre1']] - 3)
        if row['genre2'] in genre_list:
            count += 3 * (genre_rating_dict[row['genre2']] - 3)
        if row['genre3'] in genre_list:
            count += 1 * (genre_rating_dict[row['genre3']] - 3)
        scores.append(count)
        count = 0
    
    # create new column in dataframe for genre score
    books_cf['genre_score'] = scores
    
    # return top books with top 10 recommendation scores among the remaining books
    recommendation = books_cf.loc[books_cf['id'].isin(recommendation_df['id'].head(len(fives)).tolist())]
    recommendation = recommendation.sort_values(by=['genre_score', 'id'], ascending=[False, True])
    recommendation = recommendation.head(10)
    
else:
    
    # return top 10 books by recommendation score
    recommendation = books_cf.loc[books_cf['id'].isin(recommendation_df['id'].head(10).tolist())]
    recommendation = recommendation.sort_values(by=['id'], ascending=True)
    recommendation = recommendation.head(10)
    
recommendation
# Out:
#         id                                              title  \
# 5613  5637                                     The Dhammapada
# 3458  3464          The Doors of Perception & Heaven and Hell
# 8438  8485  The Element: How Finding Your Passion Changes ...
# 788    790  The Four Agreements: A Practical Guide to Pers...
# 4986  5005                 Feeling Good: The New Mood Therapy
# 1309  1314                              The Origin of Species
# 1687  1692  He's Just Not That Into You: The No-Excuses Tr...
# 6591  6620  The Language Instinct: How the Mind Creates La...
# 7957  8000  The Red Queen: Sex and the Evolution of Human ...
# 5515  5537  The Blank Slate: The Modern Denial of Human Na...
#
#                                                 authors  year       genre1  \
# 5613  Anonymous, Ananda Maitreya, Thich Nhat Hanh, B...  -500   philosophy
# 3458                                      Aldous Huxley  1956   philosophy
# 8438                          Ken Robinson, Lou Aronica  2009    self-help
# 788                                         Miguel Ruiz  1997  non-fiction
# 4986                                     David D. Burns  1980  non-fiction
# 1309                                     Charles Darwin  1859      science
# 1687                        Greg Behrendt, Liz Tuccillo  2004  non-fiction
# 6591                                      Steven Pinker  1994  non-fiction
# 7957                                        Matt Ridley  1993  non-fiction
# 5515                                      Steven Pinker  2002      science
#
#            genre2       genre3  \
# 5613  non-fiction     classics
# 3458  non-fiction   psychology
# 8438   psychology  non-fiction
# 788     self-help   philosophy
# 4986    self-help   psychology
# 1309  non-fiction     classics
# 1687    self-help    chick-lit
# 6591      science   psychology
# 7957      science   psychology
# 5515   psychology  non-fiction
#
#                                         small_image_url  genre_score
# 5613  https://s.gr-assets.com/assets/nophoto/book/50...         16.8
# 3458  https://images.gr-assets.com/books/1375947566s...         16.3
# 8438  https://s.gr-assets.com/assets/nophoto/book/50...         16.1
# 788   https://s.gr-assets.com/assets/nophoto/book/50...         16.0
# 4986  https://s.gr-assets.com/assets/nophoto/book/50...         15.5
# 1309  https://s.gr-assets.com/assets/nophoto/book/50...         14.3
# 1687  https://s.gr-assets.com/assets/nophoto/book/50...         14.0
# 6591  https://s.gr-assets.com/assets/nophoto/book/50...         14.0
# 7957  https://s.gr-assets.com/assets/nophoto/book/50...         14.0
# 5515  https://s.gr-assets.com/assets/nophoto/book/50...         13.6

# %% [markdown]
# This gives us a 10 book recommendation.
